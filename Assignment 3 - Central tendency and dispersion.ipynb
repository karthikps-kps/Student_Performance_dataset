# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv(r"D:\Personal files\Data science Materials\ICT Academy_Materials\Data sets\StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
#  # 1. Find out how many males and females participated in the test.

# %%
df.gender.value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
#     Females who attended the exam = 518
#     Males who attended the exam = 482

# %% [markdown]
# # 2. What do you think about the students' parental level of education?

# %%
df['total marks']=((df['math score']+df['reading score']+df['writing score']))

# %%
df.head(2)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none           0             17             10
# 1                    none           8             24             23
#
#    total marks
# 0           27
# 1           55

# %%
df.groupby(['parental level of education','total marks']).size().reset_index()
# Out:
#     parental level of education  total marks  0
# 0            associate's degree           95  1
# 1            associate's degree          119  1
# 2            associate's degree          123  1
# 3            associate's degree          130  1
# 4            associate's degree          131  1
# ..                          ...          ... ..
# 588            some high school          267  2
# 589            some high school          270  1
# 590            some high school          274  1
# 591            some high school          289  1
# 592            some high school          297  1
#
# [593 rows x 3 columns]

# %%
df['total marks'].mean()
# Out:
# 203.315

# %% [markdown]
#     From the below graph we can understand that the mean value of the total marks wrt the educational qualification of the parents. Graph shows apart from students with parental eductions from 'some high school' and 'high school' all the other scored above  mean value(203.315).

# %%
plt.figure(figsize=(5,5))
sns.barplot(df['parental level of education'],df['total marks'])
plt.xticks(rotation=60)
plt.ylim(0,300)
plt.axhline(y = 203.312, color = 'r', linestyle = 'dashed', label = "Mean value line")
plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper center')
plt.show()
# Out:
# C:\Users\karth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# # 3. Who scores the most on average for math, reading and writing based on
#
# #                ● Gender
#
# #                ● Test preparation course

# %%
df.mean()
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_2820\3698961737.py:1: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# math score        66.001
# reading score     69.195
# writing score     68.119
# total marks      203.315
# dtype: float64

# %%
plt.figure(figsize=(15,5))

plt.subplots_adjust(left=0.125, bottom=0.1, right=1.0, top=1.0,wspace=0.8, hspace=0.2)

plt.subplot(131)

plt.title('Math Scores')

sns.barplot(hue="gender", y="math score", x="test preparation course", data=df,palette='bright')
plt.axhline(y = 66.067, color = 'r', linestyle = 'dashed', label = "avg math score")
plt.legend(bbox_to_anchor = (1.3, 1), loc = 'upper center')


plt.subplot(132)

plt.title('Reading Scores')
sns.barplot (hue="gender", y="reading score", x="test preparation course", data=df,palette='hls')
plt.axhline(y = 69.117, color = 'g', linestyle = '-', label = "avg reading score")
plt.legend(bbox_to_anchor = (1.35, 1), loc = 'upper center')

plt.subplot(133)

plt.title('Writing Scores')
sns.barplot (hue="gender", y="writing score", x="test preparation course", data=df,palette='colorblind')
plt.axhline(y = 67.997, color = 'b', linestyle = ':', label = "avg writing score")
plt.legend(bbox_to_anchor = (1.4, 1), loc = 'upper center')

# %% [markdown]
# 4. What do you think about the scoring variation for math, reading and writing based on
#
#     ● Gender
#
#     ● Test preparation course

# %% [markdown]
#     Refer the below 6 graphs for the analysis of variation for math, reading and writing.

# %%
plt.figure(figsize=(15,5))

sns.set_palette('bright') 
plt.figure(figsize=(15,6))
sns.histplot(x='math score', data=df, kde=True, hue='gender')
plt.title('math scores of male and female')
plt.show()

sns.set_palette('hls') 
plt.figure(figsize=(15,6))
sns.histplot(x='reading score', data=df, kde=True, hue='gender')
plt.title('reading scores of male and female')
plt.show()

sns.set_palette('colorblind') 
plt.figure(figsize=(15,6))
sns.histplot(x='writing score', data=df, kde=True, hue='gender')
plt.title('writing scores of male and female')
plt.show()

# %%
plt.figure(figsize=(15,5))

sns.set_palette('bright') 
plt.figure(figsize=(15,6))
sns.histplot(x='math score', data=df, kde=True, hue='test preparation course')
plt.title('math scores wrt test preparation course')
plt.show()

sns.set_palette('hls') 
plt.figure(figsize=(15,6))
sns.histplot(x='reading score', data=df, kde=True, hue='test preparation course')
plt.title('reading scores wrt test preparation course')
plt.show()

sns.set_palette('colorblind') 
plt.figure(figsize=(15,6))
sns.histplot(x='writing score', data=df, kde=True, hue='test preparation course')
plt.title('writing scores wrt test preparation course')
plt.show()

# %% [markdown]
# # 5.The management needs your help to give bonus points to the top 25% of
# #      students based on their math score, so how will you help the management
# #      to achieve this.

# %% [markdown]
# By refering the below boxplot and the data frame, mangement will be able to come to a conclusion on providing the bonus points.

# %%
df.describe()
# Out:
#         math score  reading score  writing score  total marks
# count  1000.000000    1000.000000    1000.000000  1000.000000
# mean     66.001000      69.195000      68.119000   203.315000
# std      15.569567      14.706436      15.226381    43.227009
# min       0.000000      17.000000      10.000000    27.000000
# 25%      57.000000      59.000000      58.000000   175.000000
# 50%      66.000000      70.000000      69.000000   206.000000
# 75%      77.000000      79.250000      79.000000   233.250000
# max     100.000000     100.000000     100.000000   300.000000

# %%
np.percentile(df['math score'], 75)
# Out:
# 77.0

# %%
sns.boxplot(data=df,y=df['math score'],palette='colorblind')
plt.show()

# %%
x=df[df['math score']>=77.0].groupby(['gender','race/ethnicity','parental level of education','lunch','test preparation course','math score']).size().reset_index()
x.rename(columns={0:'Count'},inplace=True)
x
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group A          associate's degree      standard
# 1    female        group A                 high school  free/reduced
# 2    female        group A                some college      standard
# 3    female        group A            some high school      standard
# 4    female        group A            some high school      standard
# ..      ...            ...                         ...           ...
# 241    male        group E            some high school      standard
# 242    male        group E            some high school      standard
# 243    male        group E            some high school      standard
# 244    male        group E            some high school      standard
# 245    male        group E            some high school      standard
#
#     test preparation course  math score  Count
# 0                      none          82      1
# 1                 completed          77      1
# 2                 completed          78      1
# 3                 completed          85      1
# 4                 completed          92      1
# ..                      ...         ...    ...
# 241               completed          87      1
# 242               completed          89      1
# 243                    none          82      1
# 244                    none          92      1
# 245                    none          94      1
#
# [246 rows x 7 columns]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       246 non-null    object
#  1   race/ethnicity               246 non-null    object
#  2   parental level of education  246 non-null    object
#  3   lunch                        246 non-null    object
#  4   test preparation course      246 non-null    object
#  5   math score                   246 non-null    int64
#  6   Count                        246 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 13.6+ KB

# %%
x.gender.value_counts()
# Out:
# male      145
# female    101
# Name: gender, dtype: int64

# %% [markdown]
# Total no of students to be awarded bonus points - 246 Nos.
#                                            male - 145 Nos.
#                                          female - 101 Nos.
